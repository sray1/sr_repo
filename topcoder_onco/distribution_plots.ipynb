# %%
# load modules
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
# load csv file of TS & DX features
df = pd.read_csv('train_feature.csv',index_col=0)
df = df.drop(['CaseID'], axis=1)
print df.shape
df.head()
# Out:
# (131, 27)
#     FGA     f1_DX       f2_DX     f3_DX        f4_DX     f5_DX       f6_DX  \
# 0  0.19  0.000178  636.979923  0.742520  1236.960925  0.071534  374.374775
# 1  0.58  0.000263  889.757091  0.848634  2939.139272  0.103400  260.825705
# 2  0.05  0.001117  503.788679  0.837511  1550.270937  0.140879  325.805807
# 3  0.09  0.013913  314.689500  0.918697  1935.295697  0.329966  373.522241
# 4  0.04  0.003780  594.823683  0.890110  2706.468779  0.212569  320.116969
#
#           f7_DX     f8_DX      f9_DX    ...           f4_TS     f5_TS  \
# 0   4310.863779  7.817773  13.343517    ...     2110.183073  0.098998
# 1  10866.799997  8.427585  13.950134    ...     2787.779327  0.105171
# 2   5697.295069  7.965670  13.029051    ...     2859.590389  0.097938
# 3   7426.493287  7.462422  11.311457    ...     2156.486873  0.099525
# 4  10231.051432  7.873309  12.599168    ...     2972.278906  0.121855
#
#         f6_TS         f7_TS     f8_TS      f9_TS    f10_TS    f11_TS  \
# ...

# %%
# draw heatmap of all features
corrmap = df.corr()
plt.figure(figsize=(13,13))
ax = sns.heatmap(corrmap,annot=True,fmt=".2f")
plt.show()

# %%
num_cols = ['f1_DX','f2_DX','f3_DX','f4_DX','f5_DX','f6_DX','f7_DX','f8_DX','f9_DX',
           'f10_DX','f11_DX','f12_DX','f13_DX']
temp_df = df[num_cols]
temp_df['FGA']=df['FGA']

for comb in num_cols:
    #g = sns.FacetGrid(temp_df, size=7)
    g = sns.lmplot(x="FGA", y=comb, data=temp_df, size=7)
    #g.map(plt.scatter,'FGA',comb, alpha=.7)
    plt.show()
# Out:
# C:\Users\Shonket\Anaconda\lib\site-packages\IPython\kernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
num_cols = ['f1_TS','f2_TS','f3_TS','f4_TS','f5_TS','f6_TS','f7_TS','f8_TS','f9_TS',
           'f10_TS','f11_TS','f12_TS','f13_TS']
temp_df = df[num_cols]
temp_df['FGA']=df['FGA']

for comb in num_cols:
    #g = sns.FacetGrid(temp_df, size=7)
    g = sns.lmplot(x="FGA", y=comb, data=temp_df, size=7)
    #g.map(plt.scatter,'FGA',comb, alpha=.7)
    plt.show()
# Out:
# C:\Users\Shonket\Anaconda\lib\site-packages\IPython\kernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
